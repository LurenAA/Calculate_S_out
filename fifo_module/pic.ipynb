# %%
import numpy as np
import matplotlib.pyplot as plt
# import sciplot
# plt.style.use(['science','ieee'])

dicBad = {
    5: [ # [ y1,y2,y3 ]
        83,82,81,80,79
    ],
    4.95: [
        75,74,73,72,71,70
    ],
    4.9: [
        68,67,66
    ],
    4.85: [
        67,66,65,64
    ],
    4.8: [
        59,58,57
    ],
    4.75: [
        59,58,57
    ],
    4.7: [
        58,57,56
    ],
    4.65: [
        51,50
    ],
    4.6:[
        51,50
    ],
    4.55: [
        44,43
    ]
}

dicOk = {
    5: [ # [ y1,y2,y3 ]
        84,85,86,87,88
    ],
    4.95: [
        76,77,78,79
    ],
    4.9: [
        69,70,71,72,73,74
    ],
    4.85:[
        68,69,70
    ],
    4.8:[
        60,61,62,63,64,65,66
    ],
    4.75:[
        60,61,62
    ],
    4.7: [
        59
    ],
    4.65: [
        52,53,54,55,56
    ],
    4.6: [
        52,53
    ],
    4.55: [
        45,46,47,48,49,50,51
    ]
}
fig, ax = plt.subplots()
# for color in ['tab:blue', 'tab:orange', 'tab:green']:
#     n = 750
#     x, y = np.random.rand(2, n)
#     # scale = 200.0 * np.random.rand(n)
#     ax.scatter(x, y, c=color, s=30, label=color,
#                 edgecolors='none')
xBadList = []
yBadList = []
for x, ys in dicBad.items():
    for y in ys:
        xBadList.append(x)
        yBadList.append(y)
ax.scatter(xBadList, yBadList, c='tab:red', s=5, label="Discontinuous", edgecolors='none')

xOkList = []
yOkList = []
for x, ys in dicOk.items():
    for y in ys:
        xOkList.append(x)
        yOkList.append(y)
ax.scatter(xOkList, yOkList, c='tab:green', s=5, label="Continuous", edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import sciplot


theoreticalDict = {
    5: 85,
    4.95: 80,
    4.9: 75,
    4.85: 71,
    4.8:  67,
    4.75: 63,
    4.7: 60,
    4.65: 56,
    4.6: 54,
    4.55: 51
}

dif = {
    5: 84,
    4.95: 76,
    4.9: 69,
    4.85: 68,
    4.8:  60,
    4.75: 60,
    4.7: 59,
    4.65: 52,
    4.6: 52,
    4.55: 45
}

xBadList = []
yBadList = []
badEdge = []

xOkList = []
yOkList = []
okEdge = []



for x, y in dif.items():
    for yo in range(y, theoreticalDict[x] + 10):
        edgeVal = 0
        if(theoreticalDict[x] == yo):
            edgeVal = 0.5
        xOkList.append(x)
        yOkList.append(yo)
        okEdge.append(edgeVal)
    for yn in range(theoreticalDict[x] -20, y):
        xBadList.append(x)
        yBadList.append(yn)
        badEdge.append(edgeVal)


    fig, ax = plt.subplots()
    ax.scatter(xBadList, yBadList, c='tab:red', s=5, label="Discontinuous", edgecolors='blue',linewidths=badEdge)
    ax.scatter(xOkList, yOkList, c='tab:green', s=5, label="Continuous", edgecolors='blue',linewidths=okEdge)

    ax.legend(loc='best', frameon=True, prop = {'size':5})
    ax.grid(True)
    plt.xlabel("Sampling rate(GSa/s)")
    plt.ylabel("Nseq(word)")

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\BaiduSyncdisk\FIFO\Calculate_S_out\fifo_module\pic.ipynb Cell 2 in <cell line: 42>()
#      <a href='vscode-notebook-cell:/d%3A/BaiduSyncdisk/FIFO/Calculate_S_out/fifo_module/pic.ipynb#W1sZmlsZQ%3D%3D?line=61'>62</a> plt.xlabel("Sampling rate(GSa/s)")
#      <a href='vscode-notebook-cell:/d%3A/BaiduSyncdisk/FIFO/Calculate_S_out/fifo_module/pic.ipynb#W1sZmlsZQ%3D%3D?line=62'>63</a> plt.ylabel("Nseq(word)")
# ---> <a href='vscode-notebook-cell:/d%3A/BaiduSyncdisk/FIFO/Calculate_S_out/fifo_module/pic.ipynb#W1sZmlsZQ%3D%3D?line=64'>65</a> plt.show()
#
# File d:\anaconda\lib\site-packages\matplotlib\pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import sciplot
plt.style.use(['science','ieee'])

discontinueList = {
    113: [],
    112: [],
    111: [],
    110: [],
    109: [4.85],
    108: [4.85],
    107: [],
    106: [],
    105: [4.9,4.95,5],
    104: [4.9,4.95,5],
    103: [4.9,4.95,5],
    102: [4.8,4.85,4.9,4.95,5],
    101: [5, 4.95, 4.9, 4.85,4.8],
    100: [5, 4.95, 4.9, 4.85,4.8],
    99: [5, 4.95, 4.9, 4.85,4.8],
    98: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7],
    97: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7],
    96: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65],
    95: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    94: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    93: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    92: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55]
}
sampleRange = [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55]

xBadList = []
yBadList = []
xOkList = []
yOkList = []

for nFifo, sampleRates in discontinueList.items():
    for s in sampleRange:
        if s in sampleRates:
            xBadList.append(s)
            yBadList.append(nFifo)
        else:
            xOkList.append(s)
            yOkList.append(nFifo)


fig, ax = plt.subplots()
ax.scatter(xBadList, yBadList, c='tab:red', s=5, label="Discontinuous", edgecolors = "blue",linewidths=[x/10 for x in xBadList])

ax.scatter(xOkList, yOkList, c='tab:green', s=5, label="Continuous")

ax.legend(loc='lower right', frameon=True, prop = {'size':5})
# ax.grid(True)
plt.xlabel("Sampling rate(GSa/s)")
plt.ylabel("Nfifo(word)")

# xy = (5 ,110)
# ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data', fontsize = 3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import os
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, ScalarFormatter, FormatStrFormatter
plt.style.use(["science", "no-latex", "ieee"])

plt.rcParams.update({'font.size': 6})

def draw_by_method(df, linedf):
    markers = {
        "Continue" : "o",
        "Discontinue" : "X"
    }

    
    ax = sns.scatterplot(
        data=df,
        x="Sampling rate",
        y="N_seq",
        hue="is_continue",
        #         col="method",
        style="is_continue",
        markers=markers,
        s=5,
        # palette="dark",
        # legend_out=False,
        # height=3,
        # aspect=1.1,
        # scatter_kws={"s": 20},
        # line_kws={"linewidth": 1},
    )
    ax.set(xlabel="Sampling rate (GSa/s)")
    ax.set(ylabel="Nseq(word)")
    ax.legend(title="")

    ax2 = sns.lineplot(data=linedf,
        x="Sampling rate",
        y="N_seq",style="type",ax=ax,
        legend=False
        )

    # subplots = ax.axes.flatten()
    
    ax.set_xticks([5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55])

# %%
import pandas as pd
theoreticalDict = {
    5: 85,
    4.95: 80,
    4.9: 75,
    4.85: 71,
    4.8:  67,
    4.75: 63,
    4.7: 60,
    4.65: 56,
    4.6: 54,
    4.55: 51
}

dif = {
    5: 84,
    4.95: 76,
    4.9: 69,
    4.85: 68,
    4.8:  60,
    4.75: 60,
    4.7: 59,
    4.65: 52,
    4.6: 52,
    4.55: 45
}

columns = ["Sampling rate", "N_seq", "is_continue"]
dataList = []
for x, y in dif.items():
    for yo in range(y, theoreticalDict[x] + 5):
        dataList.append([x, yo, "Continue"])
    for yn in range(theoreticalDict[x] -15, y):
        dataList.append([x, yn, "Discontinue"])

df = pd.DataFrame(dataList, columns=columns)
# print(df)

# type : 理论值："t"  实际值 "p"
columns2 = ["Sampling rate", "N_seq", "type"]
dataList2 = []
for x, y in theoreticalDict.items():
    dataList2.append([x, y, "t"])
for x, y in dif.items():
    dataList2.append([x, y, "p"])
df2 = pd.DataFrame(dataList2, columns=columns2)
# print(theoreticalDf)
draw_by_method(df,df2)
# Out:
# c:\ProgramData\miniconda3\lib\site-packages\matplotlib\ticker.py:2937: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# import sciplot
import os
import pandas as pd
import numpy as np
import scienceplots

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, ScalarFormatter, FormatStrFormatter
plt.style.use(["science", "no-latex", "ieee"])

plt.rcParams.update({'font.size': 6})

def draw_by_method(df, linedf):
    markers1 = {
        "Continue" : "o",
        "Discontinue" : "X"
    }

    
    ax = sns.scatterplot(
        data=df,
        x="Sampling rate",
        y="N_fifo",
        hue="is_continue",
        #         col="method",
        style="is_continue",
        markers=markers1,
        s=5,
        # palette="dark",
        # legend_out=False,
        # height=3,
        # aspect=1.1,
        # scatter_kws={"s": 20},
        # line_kws={"linewidth": 1},
    )
    ax.set(xlabel="Sampling rate (GSa/s)")
    ax.set(ylabel="Nbuffer (word)")
    ax.legend(title="")

    ax2 = sns.lineplot(data=linedf,
        x="Sampling rate",
        y="N_fifo",style="type",ax=ax,
        legend=False
        )

    # subplots = ax.axes.flatten()
    
    ax.set_xticks([5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55])
    ax.set_yticks(range(70, 117, 2))

theoreticalDict = {
    5: 113,
    4.95: 112,
    4.9: 111,
    4.85: 110,
    4.8:  109,
    4.75: 108,
    4.7: 108,
    4.65: 107,
    4.6: 106,
    4.55: 105
}
dif = {
    5: 106,
    4.95: 106,
    4.9: 106,
    4.85: 110,
    4.8:  103,
    4.75: 99,
    4.7: 99,
    4.65: 97,
    4.6: 96,
    4.55: 96
}

discontinueList = {
    115: [],
    114: [],
    113: [],
    112: [],
    111: [],
    110: [],
    109: [4.85],
    108: [4.85],
    107: [],
    106: [],
    105: [4.9,4.95,5],
    104: [4.9,4.95,5],
    103: [4.9,4.95,5],
    102: [4.8,4.85,4.9,4.95,5],
    101: [5, 4.95, 4.9, 4.85,4.8],
    100: [5, 4.95, 4.9, 4.85,4.8],
    99: [5, 4.95, 4.9, 4.85,4.8],
    98: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7],
    97: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7],
    96: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65],
    95: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    94: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    93: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    92: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    91: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    90: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    89: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    88: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    87: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    86: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    85: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    84: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    83: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    82: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    82: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    81: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    80: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    79: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    78: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    77: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    76: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    75: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    74: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    73: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    72: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    71: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    70: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
    69: [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55],
}
sampleRange = [5, 4.95, 4.9, 4.85,4.8, 4.75, 4.7, 4.65, 4.6, 4.55]

columns = ["Sampling rate", "N_fifo", "is_continue"]
dataList = []
for nFifo, sampleRates in discontinueList.items():
    for s in sampleRange:
        if (theoreticalDict[s] - 30 >  nFifo) or (
            nFifo > theoreticalDict[s] + 2
        ):
            continue
        if s in sampleRates:
            dataList.append([s, nFifo, "Discontinue"])
        else:
            dataList.append([s, nFifo, "Continue"])

df = pd.DataFrame(dataList, columns=columns)


# type : 理论值："t"  实际值 "p"
columns2 = ["Sampling rate", "N_fifo", "type"]
dataList2 = []
for x, y in theoreticalDict.items():
    dataList2.append([x, y, "t"])
for x, y in dif.items():
    dataList2.append([x, y, "p"])
df2 = pd.DataFrame(dataList2, columns=columns2)
draw_by_method(df,df2)
# Out:
# c:\ProgramData\miniconda3\lib\site-packages\matplotlib\ticker.py:2937: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# findfont: Generic family 'serif' not found because none of the following families were found: Times
# ...
